# %% [markdown]
# <a href="https://colab.research.google.com/github/Aparna471/my_projects/blob/main/Data_Science_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualization using matplotlib

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax = plt.axes(projection = "3d")
zline = np.linspace(0,15,100)
xline = np.sin(zline)
yline =np.cos(zline)
ax.plot3D(xline , yline , zline , "gray")

z = 15 * np.random.random(100)
x =np.sin(z) + 0.1* np.random.randn(100)
y = np.cos(z) + 0.1* np.random.randn(100)
ax.scatter3D(x , y , z, c=z, cmap = "Greens");

# %% [markdown]
# 3D counter plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline
def f(x,y):
  return np.sin(np.sqrt(x**2 + y**2))
x = np.linspace(0,10,20)
y = np.linspace(0,10,20)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)
fig = plt.figure()
ax = plt.axes(projection ="3d")
ax.contour3D(X,Y,Z,50,cmap = "binary")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits import mplot3d
theta = 6* np.pi *(np.random.random(1000))
r = 5 * np.random.random(1000)
x =np.ravel(r *np.sin(theta))
y = np.ravel(r* np.cos(theta))
z = f(x,y)
ax = plt.axes(projection = "3d")
ax.scatter(x , y , z , c = z ,cmap = "viridis" ,linewidth = 0.5)
